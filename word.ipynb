# %%
filename = 'pp.txt'
with open(filename) as f:
    mytext = f.read()

# %%
mytext=mytext[100000:200000]

# %%
ll=mytext.split('.')

myll=[i.strip('\n') for i in ll]

newll=[]
for i in myll:
    if len(i)>30:
        newll.append(i)

# %% [markdown]
# # 读取肽段

# %%
mydict={}
mydict['npk']=['neuropeptide K','NPK']
mydict['pacap27']=['Pituitary adenylate cyclase activating polypeptide 27','PACAP27']

mydict['vip']=["Vasoactive intestinal peptide",'VIP']
mydict['dynorphin A']=['dynorphin A']
mydict['neuromedin B']=['neuromedin B']
mydict['neuromedin U23']=['neuromedin U23']
mydict['Neurokinin A']=['Neurokinin A','NKA']
mydict['beta endorphin']=['beta endorphin','β Endorphin']
mydict['Orexin B']=['Orexin B']
mydict['Galanin']=['Galanin']
mydict['Melanotropin alpha']=['Melanotropin alpha','α-Melanotropin']
mydict['nociceptin']=['nociceptin']
mydict['AVP']=['Arginine vasopressin'] 
mydict['Oxytocin']=['Oxytocin']
mydict['CRH']=['CRH','CRF','corticotropin releasing hormone']
mydict['Manserin']=['Manserin']

# %% [markdown]
# # 读取behavior

# %%
mybh={}
filename = 'bh.txt'
with open(filename) as f:
    mybh = f.read()
newbh=mybh.strip('\n').split(',')

# %%
for i in newll:
    for j in mydict.keys():
        for k in mydict[j]:
            if k in i:
                print('检查到的含肽句子：')
                print(i)
                print('####################\n')
                print('包含的肽段',k,'\n')
                for m in newbh:
                    if m in i:
                        
                        print('改句中含有的behavior：',m)
                print('下一只猪猪(*^_^*)')
# Out:
# 检查到的含肽句子：
#  Galanin has been hypothesized to interact with the leptin signaling
# system, but literature investigating colocalization of LepRb and galanin has been
# inconsistent, which is likely due to technical difficulties to visualize both
# ####################
#
# 包含的肽段 Galanin
#
# 下一只猪猪(*^_^*)
# 检查到的含肽句子：
# ) injection of NPW elevates plasma corticosterone levels, the intravenous
# administration of NPW in conjunction with a corticotropin-releasing hormone (CRH)
# antagonist blocks NPW-induced corticosterone secretion
# ####################
#
# 包含的肽段 CRH
#
# 下一只猪猪(*^_^*)
# 检查到的含肽句子：
#  The aim of
# the present study was to ascertain if NPW's role in feeding regulation is
# mediated (or not) through corticotropin-releasing hormone (CRH)-containing
# neurons
# ####################
#
# 包含的肽段 CRH
#
# 下一只猪猪(*^_^*)
# 检查到的含肽句子：
#  We found that NPW-containing axon terminals make synapses with
# CRH-immunoreactive cell bodies and dendritic processes in the hypothalamic
# ...
